# %% [markdown]
# <a href="https://colab.research.google.com/github/cho52o/Python_Application2020/blob/main/15_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualization
#
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %% [markdown]
# ## Basic plotting: plot

# %%
# 시계열 그림
ts=pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000', periods=1000))
ts=ts.cumsum()
# ts
ts.plot()

# %%
# 여러 열의 시계열 그림
df=pd.DataFrame(np.random.randn(1000, 4),index=ts.index, columns=list('ABCD'))
df=df.cumsum()
plt.figure()
df.plot()

# %% [markdown]
# ## Bar plots

# %%
plt.figure()
df.iloc[5].plot.bar()
plt.axhline(0, color='k')

# %%
df2=pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot.bar()

# %%
df2
# Out:
#           a         b         c         d
# 0  0.026736  0.135160  0.081628  0.218226
# 1  0.840397  0.383442  0.025033  0.767177
# 2  0.874671  0.795456  0.612539  0.137176
# 3  0.778809  0.770666  0.760862  0.420640
# 4  0.292443  0.112872  0.764944  0.721856
# 5  0.207599  0.406167  0.516928  0.198909
# 6  0.184115  0.946874  0.637736  0.638475
# 7  0.695274  0.797632  0.816424  0.704577
# 8  0.964409  0.868842  0.611167  0.576657
# 9  0.882875  0.905223  0.132871  0.880017

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.barh(stacked=True)

# %% [markdown]
# ## Histograms

# %%
df4=pd.DataFrame({'a': np.random.randn(1000) +1, 'b': np.random.randn(1000),'c': np.random.randn(1000) -1}, columns=['a', 'b', 'c'])
plt.figure()
df4.plot.hist(alpha=0.5)

# %%
plt.figure()
df4.plot.hist(stacked=True, bins=20) # 20~30정도가 적당

# %%
plt.figure()
df['A'].diff().hist()

# %% [markdown]
# ## Box plots

# %%
df=pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box()

# %%
df.plot.box(vert=False)

# %% [markdown]
# ## Scatter plot

# %%
df=pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b')

# %%
df.plot.scatter(x='a', y='b', c='c', s=50)

# %%
df.plot.scatter(x='a', y='b', s=df['c'] * 200)

# %% [markdown]
# # Plotly Python Open Source Graphing Library
#
# * https://plotly.com/python/

# %%
# !pip install plotly==4.8.1

# %%
import plotly.express as px

# %%
fig=px.scatter(x=[0, 1, 2, 3, 4], y=[0, 1, 4, 9, 16])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7cfafde0-9463-4713-b3d6-f16b7f99a549" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7cfafde0-9463-4713-b3d6-f16b7f99a549")) {
#                     Plotly.newPlot(
#                         '7cfafde0-9463-4713-b3d6-f16b7f99a549',
# ...

# %%
# x and y given as DataFrame columns
df=px.data.iris() # iris is a pandas DataFrame
fig=px.scatter(df, x="sepal_width", y="sepal_length")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5fff0945-f69a-4d32-b175-ccf5273e3895" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5fff0945-f69a-4d32-b175-ccf5273e3895")) {
#                     Plotly.newPlot(
#                         '5fff0945-f69a-4d32-b175-ccf5273e3895',
# ...

# %%
df=px.data.iris()
fig=px.scatter(df, x="sepal_width", y="sepal_length", color="species",size='petal_length', hover_data=['petal_width'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="efa73275-6ceb-4e74-b96d-0674a667061c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("efa73275-6ceb-4e74-b96d-0674a667061c")) {
#                     Plotly.newPlot(
#                         'efa73275-6ceb-4e74-b96d-0674a667061c',
# ...

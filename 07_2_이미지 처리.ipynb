# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (20, 10)

# %%
from tkinter.filedialog import askopenfilename # 파일 탐색기 사용

# %%
image_dark = cv2.imread('C:/Users/choye/Python_Application/image/dark.png')

# %%
# 이미지를 출력
plt.imshow(cv2.cvtColor(image_dark, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 감마 보정 - Gamma correction

# %%
gamma = 0.5

LookUpTable = np.empty((1,256), np.uint8)
for i in range(256):
    LookUpTable[0,i] = np.clip(pow(i / 255.0, gamma) * 255.0, 0, 255)
image_gamma = cv2.LUT(image_dark, LookUpTable)

# RGB로 변환
img_rgb = cv2.cvtColor(image_gamma, cv2.COLOR_BGR2RGB)

# 이미지를 출력
plt.imshow(img_rgb)
plt.show()

# %% [markdown]
# # 임계처리(thresholding)
# * 이미지 행렬에서 하나의 픽셀값을 사용자가 지정한 기준값을

# %%
# 흑백 이미지
image_gray = cv2.cvtColor(image_dark, cv2.COLOR_BGR2GRAY)

# 이미지 출력
plt.imshow(image_gray, 'gray')
plt.show()

# %%
_, thresh = cv2.threshold(image_gray, 16, 255, cv2.THRESH_BINARY)

# 이미지 출력
plt.imshow(thresh, 'gray')
plt.show()

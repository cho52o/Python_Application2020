# %% [markdown]
# # Library - OpenCV

# %%
### 라이브러리 설치
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\choye\anaconda3\lib\site-packages (4.2.0.34)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\choye\anaconda3\lib\site-packages (from opencv-python) (1.18.2)

# %%
import cv2

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
### 파일 탐색기 사용
from tkinter.filedialog import askopenfilename

# %%
img_file = askopenfilename()
img_file
# Out:
# 'C:/Users/choye/Python_Application/image/sample-color.png'

# %% [markdown]
# # 이미지 로드

# %%
image_bgr = cv2.imread(img_file)
#RGB로 변환
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
#이미지 출력
plt.figure(figsize=(20, 10))
plt.imshow(image_rgb)
plt.show()

# %%
### 픽셀 확인
image_bgr[0,0,:]
# Out:
# array([ 88, 116, 116], dtype=uint8)

# %%
image_bgr.shape
# Out:
# (512, 768, 3)

# %%
# 흑백 이미지
image = cv2.imread(img_file, cv2.IMREAD_GRAYSCALE)

# %%
image.shape
# Out:
# (512, 768)

# %%
plt.figure(figsize=(20, 10))
plt.imshow(image, 'gray')
plt.show()
